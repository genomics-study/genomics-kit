# %% [markdown]
# # Introduction

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %%
import sys
import os

paths = ['./omicron/src/preprocessing/', './omicron/src/validation/', './omicron/src/classificators/']
for path in paths:
    sys.path.append(os.path.abspath(path))

from preproc import *
from CV import *

# %% [markdown]
# ## Loading dataset
#
# Preporcessing script performs csv file loading, removing unwanted columns and filling NaNs with given value

# %%
df_phen, df_xp = read_dfs(nan_fill=0)

# %%
print(df_xp.shape)
print(df_phen.shape)
# Out:
# (54, 34476)
# (54, 203)

# %%
df_phen[['"tau_DayDBP"', '"tau_NightSBP"']]
# Out:
#     "tau_DayDBP"  "tau_NightSBP"
# 0       0.108125        0.059130
# 1       0.132000        0.077021
# 2       0.129146        0.080000
# 3       0.098706        0.090000
# 4       0.131250        0.033920
# 5       0.082963        0.082358
# 6       0.160533        0.121515
# 7       0.096154        0.065189
# 8       0.112048        0.081287
# 9       0.101474        0.066612
# 10      0.067241        0.082435
# 11      0.115843        0.083784
# 12      0.098280        0.089134
# 13      0.089111        0.138095
# 14      0.083214        0.102202
# 15      0.105823        0.072788
# 16      0.153088        0.073471
# 17      0.098557        0.052645
# 18      0.097941        0.052632
# 19      0.084639        0.077115
# 20      0.085213        0.104803
# 21      0.120990        0.084909
# 22      0.105062        0.085243
# 23      0.125000        0.140485
# 24      0.109176        0.078788
# 25      0.141098        0.102353
# 26      0.101412        0.111518
# 27      0.126429        0.072545
# 28      0.106494        0.066239
# 29      0.119000        0.092551
# 30      0.133049        0.112124
# 31      0.144933        0.067818
# 32      0.091429        0.109238
# 33      0.143556        0.083069
# 34      0.098636        0.082857
# 35      0.145395        0.107158
# 36      0.122581        0.118561
# 37      0.127333        0.101081
# 38      0.118148        0.088000
# 39      0.183521        0.086429
# 40      0.106512        0.069796
# 41      0.107011        0.051026
# 42      0.160380        0.095573
# 43      0.135270        0.069037
# 44      0.126341        0.068413
# 45      0.111667        0.103828
# 46      0.135408        0.062553
# 47      0.083441        0.115984
# 48      0.119140        0.061707
# 49      0.115543        0.088019
# 50      0.086818        0.110291
# 51      0.125455        0.084323
# 52      0.117703        0.115980
# 53      0.123049        0.069478

# %% [markdown]
# ## Performing recon data vizualization

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib

# %%
pca = PCA(n_components=20)
components = pca.fit_transform(df_xp)

# %%
tsne = TSNE(n_components=2, perplexity=15.0, method='barnes_hut')
components = tsne.fit_transform(components)
components_dataframe = pd.DataFrame(data=components)

# %%
x = components_dataframe[0]
y = components_dataframe[1]
label = df_phen[' "grupa"']
colors = ['red','green','blue','purple', 'black', 'orange']
plt.figure(figsize=(15,10))
plt.scatter(x, y, c=label, cmap=matplotlib.colors.ListedColormap(colors))

# %%
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt

pca = PCA(n_components=3)
components = pca.fit_transform(df_xp)
components_dataframe = pd.DataFrame(data=components)
x = components_dataframe[0]
y = components_dataframe[1]
z = components_dataframe[2]
label = df_phen[' "grupa"']
colors = ['red','green','blue','purple', 'black', 'yellow']

fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c=label, cmap=matplotlib.colors.ListedColormap(colors))
